# %% [markdown]
# # Assignment Day 27 | 12th August 2020

# %% [markdown]
# #### Junior Peña

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score 
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dfknn = df.drop(['Name','PassengerId','Ticket','Cabin'],axis=1)
dfknn.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
le = LabelEncoder()
dfknn['Sex'] = le.fit_transform(dfknn['Sex'])
dfknn['Embarked'] = le.fit_transform(dfknn['Embarked'])

# %%
def knn_data(kd):
    x = dfknn.drop(['Pclass'],axis=1)
    y = dfknn['Pclass']
    a = []
    b = []
    
    for i in range(1,kd):
        knn = KNeighborsClassifier(n_neighbors = i)
        a.append(i)

        print(f" \nHere the K value is: {i} ")
              
        x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2, random_state = 10)
        model = knn.fit(x_train,y_train)
        pred = model.predict(x_test)
              
        score = model.score(x_test,y_test)
        b.append(score)
              
        print(f"\nThe Accuracy score when K is {i} ", score)
        print(f"Confusion Matrix when K is {i} \n", confusion_matrix(y_test, pred))
        
              
    plt.plot(a,b)
    plt.show()

# %%
knn_data(268)
# Out:
#
# Here the K value is: 1
#
# The Accuracy score when K is 1  0.8876404494382022
# Confusion Matrix when K is 1
#  [[42  4  0]
#  [ 1 25  5]
#  [ 0 10 91]]
#
# Here the K value is: 2
#
# The Accuracy score when K is 2  0.9044943820224719
# Confusion Matrix when K is 2
#  [[44  2  0]
#  [ 2 27  2]
#  [ 0 11 90]]
#
# Here the K value is: 3
#
# The Accuracy score when K is 3  0.9044943820224719
# Confusion Matrix when K is 3
#  [[43  2  1]
#  [ 1 24  6]
#  [ 1  6 94]]
#
# Here the K value is: 4
#
# The Accuracy score when K is 4  0.9044943820224719
# Confusion Matrix when K is 4
#  [[45  1  0]
#  [ 2 26  3]
#  [ 1 10 90]]
#
# Here the K value is: 5
#
# The Accuracy score when K is 5  0.9044943820224719
# Confusion Matrix when K is 5
#  [[43  3  0]
#  [ 1 23  7]
#  [ 2  4 95]]
#
# Here the K value is: 6
#
# The Accuracy score when K is 6  0.8820224719101124
# Confusion Matrix when K is 6
#  [[44  2  0]
#  [ 2 22  7]
#  [ 2  8 91]]
#
# Here the K value is: 7
#
# ...
