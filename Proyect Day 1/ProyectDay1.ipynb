# %%
import os
import sys
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from scipy.io import loadmat
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Import Pyod and the methods

# %%
from pyod.models.pca import PCA
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.lof import LOF
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.hbos import HBOS
from pyod.models.abod import ABOD
from pyod.models.iforest import IForest
from pyod.models.feature_bagging import FeatureBagging

# %% [markdown]
# ## Import Metrics Package

# %%
from pyod.utils.utility import standardizer
from pyod.utils.utility import precision_n_scores
from sklearn.metrics import roc_auc_score

# %%
mat_file_list=['arrhythmia.mat','cardio.mat','glass.mat','ionosphere.mat','letter.mat','lympho.mat','mnist.mat','musk.mat','optdigits.mat','pendigits.mat','pima.mat','satellite.mat','satimage-2.mat','shuttle.mat','shuttle.mat','vertebral.mat','vowels.mat','wbc.mat']

# %%
mat_file_list
# Out:
# ['arrhythmia.mat',
#  'cardio.mat',
#  'glass.mat',
#  'ionosphere.mat',
#  'letter.mat',
#  'lympho.mat',
#  'mnist.mat',
#  'musk.mat',
#  'optdigits.mat',
#  'pendigits.mat',
#  'pima.mat',
#  'satellite.mat',
#  'satimage-2.mat',
#  'shuttle.mat',
#  'shuttle.mat',
#  'vertebral.mat',
#  'vowels.mat',
#  'wbc.mat']

# %% [markdown]
# ## Specifying the columns

# %%
df_columns=['Data','#Sample','#Dimensions','Outlier Perc','PCA','MCD','OCSVM','LOF','CBLOF','KNN','HBOS','ABOD','IFOREST','FEATUREBAGGING']

# %% [markdown]
# ## Precision Time and Roc evolution tables creation

# %%
roc_df=pd.DataFrame(columns=df_columns)
prn_df=pd.DataFrame(columns=df_columns)
time_df=pd.DataFrame(columns=df_columns)

# %%
print(roc_df,prn_df,time_df)
# Out:
# Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: [] Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: [] Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: []

# %% [markdown]
# ## Exploring the Mat files

# %%
from time import time

# %%
random_state = np.random.RandomState(42)
for mat_file in mat_file_list:
    print("\n... Processing",mat_file,'.....')
    mat = loadmat(mat_file)
    
    X = mat['X']
    y = mat['y'].ravel()
    
    outliers_fraction = np.count_nonzero(y) / len(y)
    outliers_percentage = round(outliers_fraction * 100, ndigits=4)
    
    roc_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    prn_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    time_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state = random_state)
    
    X_train_norm, X_test_norm = standardizer(X_train, X_test)
    
    classifiers = {'Angle-based Outlier Detector (ABOD)' : ABOD(contamination=outliers_fraction), 
                  'Cluster-based Local Outlier Factor': CBLOF(contamination=outliers_fraction,check_estimator=False ,random_state=random_state),
                  'Feature Bagging': FeatureBagging(contamination=outliers_fraction, random_state=random_state),
                  'Historgram-base Outlier Detection (HBOS)': HBOS(contamination=outliers_fraction),
                  'Isolation Forest' : IForest(contamination=outliers_fraction, random_state=random_state),
                  'K Nearest Neighbors (KNN)': KNN(contamination=outliers_fraction),
                  'Local Outlier Factor (LOF)' : LOF(contamination=outliers_fraction),
                  'Minimum Covariance Determinant (MCD)': MCD(contamination=outliers_fraction, random_state=random_state),
                  'One-class SVM (OCSVM)': OCSVM(contamination=outliers_fraction),
                  'Principal Component Analysis (PCA)': PCA(contamination=outliers_fraction, random_state=random_state)}
    for clf_name, clf in classifiers.items():
        t0 = time()
        clf.fit(X_train_norm)
        test_scores = clf.decision_function(X_test_norm)
        t1 = time()
        duration = round(t1-t0, 4)
        time_list.append(duration)
        
        roc = round(roc_auc_score(y_test, test_scores), 4)
        prn = round(precision_n_scores(y_test, test_scores), 4)
        
        print(f"{clf_name} ROC: {roc}, precision @ rank n: {prn}, execution time: {duration}s' ")
        
        roc_list.append(roc)
        prn_list.append(prn)
        
    temp_df = pd.DataFrame(time_list).transpose()
    temp_df.columns = df_columns
    time_df = pd.concat([time_df, temp_df], axis=0)
    
    temp_df = pd.DataFrame(roc_list).transpose()
    temp_df.columns = df_columns
    roc_df = pd.concat([roc_df, temp_df], axis=0)
    
    temp_df = pd.DataFrame(prn_list).transpose()
    temp_df.columns = df_columns
    prn_df = pd.concat([prn_df, temp_df], axis=0)
# Out:
# ... Processing arrhythmia.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.7687, precision @ rank n: 0.3571, execution time: 1.0649s'
# Cluster-based Local Outlier Factor ROC: 0.7684, precision @ rank n: 0.4643, execution time: 1.6181s'
# Feature Bagging ROC: 0.7799, precision @ rank n: 0.5, execution time: 0.6234s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.8511, precision @ rank n: 0.5714, execution time: 1.8258s'
# Isolation Forest ROC: 0.8527, precision @ rank n: 0.5714, execution time: 0.3427s'
# K Nearest Neighbors (KNN) ROC: 0.782, precision @ rank n: 0.5, execution time: 0.069s'
# Local Outlier Factor (LOF) ROC: 0.7787, precision @ rank n: 0.4643, execution time: 0.0625s'
# Minimum Covariance Determinant (MCD) ROC: 0.8228, precision @ rank n: 0.4286, execution time: 0.5854s'
# One-class SVM (OCSVM) ROC: 0.7986, precision @ rank n: 0.5, execution time: 0.0377s'
# Principal Component Analysis (PCA) ROC: 0.7997, precision @ rank n: 0.5, execution time: 0.0469s'
#
# ... Processing cardio.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.5763, precision @ rank n: 0.1875, execution time: 0.3814s'
# Cluster-based Local Outlier Factor ROC: 0.8221, precision @ rank n: 0.4844, execution time: 0.1805s'
# Feature Bagging ROC: 0.4879, precision @ rank n: 0.1406, execution time: 0.943s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.8453, precision @ rank n: 0.4688, execution time: 0.0101s'
# Isolation Forest ROC: 0.9414, precision @ rank n: 0.5, execution time: 0.4605s'
# K Nearest Neighbors (KNN) ROC: 0.6959, precision @ rank n: 0.2812, execution time: 0.1856s'
# Local Outlier Factor (LOF) ROC: 0.4715, precision @ rank n: 0.125, execution time: 0.1192s'
# Minimum Covariance Determinant (MCD) ROC: 0.8778, precision @ rank n: 0.3906, execution time: 0.5936s'
# One-class SVM (OCSVM) ROC: 0.9507, precision @ rank n: 0.5938, execution time: 0.0988s'
# Principal Component Analysis (PCA) ROC: 0.9638, precision @ rank n: 0.6875, execution time: 0.0s'
#
# ... Processing glass.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.7104, precision @ rank n: 0.25, execution time: 0.0583s'
# Cluster-based Local Outlier Factor ROC: 0.8506, precision @ rank n: 0.25, execution time: 0.0588s'
# Feature Bagging ROC: 0.7043, precision @ rank n: 0.25, execution time: 0.0503s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.6524, precision @ rank n: 0.0, execution time: 0.002s'
# Isolation Forest ROC: 0.7195, precision @ rank n: 0.25, execution time: 0.3516s'
# K Nearest Neighbors (KNN) ROC: 0.7805, precision @ rank n: 0.25, execution time: 0.0181s'
# Local Outlier Factor (LOF) ROC: 0.7774, precision @ rank n: 0.25, execution time: 0.0s'
# Minimum Covariance Determinant (MCD) ROC: 0.7165, precision @ rank n: 0.0, execution time: 0.0402s'
# One-class SVM (OCSVM) ROC: 0.6189, precision @ rank n: 0.25, execution time: 0.0s'
# Principal Component Analysis (PCA) ROC: 0.622, precision @ rank n: 0.25, execution time: 0.0s'
#
# ... Processing ionosphere.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.9004, precision @ rank n: 0.8214, execution time: 0.0904s'
# Cluster-based Local Outlier Factor ROC: 0.8952, precision @ rank n: 0.8036, execution time: 0.0605s'
# Feature Bagging ROC: 0.8933, precision @ rank n: 0.75, execution time: 0.0784s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.5195, precision @ rank n: 0.3393, execution time: 0.0101s'
# Isolation Forest ROC: 0.8309, precision @ rank n: 0.6607, execution time: 0.4242s'
# K Nearest Neighbors (KNN) ROC: 0.9134, precision @ rank n: 0.8393, execution time: 0.0156s'
# Local Outlier Factor (LOF) ROC: 0.8989, precision @ rank n: 0.75, execution time: 0.0156s'
# Minimum Covariance Determinant (MCD) ROC: 0.9399, precision @ rank n: 0.8571, execution time: 0.0534s'
# One-class SVM (OCSVM) ROC: 0.8372, precision @ rank n: 0.7143, execution time: 0.0s'
# Principal Component Analysis (PCA) ROC: 0.7971, precision @ rank n: 0.5893, execution time: 0.0156s'
#
# ... Processing letter.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.8465, precision @ rank n: 0.275, execution time: 0.354s'
# Cluster-based Local Outlier Factor ROC: 0.7423, precision @ rank n: 0.175, execution time: 0.1159s'
# Feature Bagging ROC: 0.866, precision @ rank n: 0.4, execution time: 0.6246s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.5728, precision @ rank n: 0.125, execution time: 0.0101s'
# Isolation Forest ROC: 0.5778, precision @ rank n: 0.05, execution time: 0.3147s'
# K Nearest Neighbors (KNN) ROC: 0.845, precision @ rank n: 0.3, execution time: 0.1112s'
# Local Outlier Factor (LOF) ROC: 0.8409, precision @ rank n: 0.325, execution time: 0.0707s'
# Minimum Covariance Determinant (MCD) ROC: 0.7499, precision @ rank n: 0.075, execution time: 0.9389s'
# One-class SVM (OCSVM) ROC: 0.5744, precision @ rank n: 0.1, execution time: 0.0826s'
# Principal Component Analysis (PCA) ROC: 0.48, precision @ rank n: 0.05, execution time: 0.002s'
#
# ... Processing lympho.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.9382, precision @ rank n: 0.4, execution time: 0.0201s'
# Cluster-based Local Outlier Factor ROC: 0.9709, precision @ rank n: 0.6, execution time: 0.0403s'
# Feature Bagging ROC: 0.9673, precision @ rank n: 0.6, execution time: 0.0282s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9964, precision @ rank n: 0.8, execution time: 0.0063s'
# Isolation Forest ROC: 0.9855, precision @ rank n: 0.6, execution time: 0.244s'
# K Nearest Neighbors (KNN) ROC: 0.9636, precision @ rank n: 0.6, execution time: 0.002s'
# Local Outlier Factor (LOF) ROC: 0.9636, precision @ rank n: 0.6, execution time: 0.008s'
# Minimum Covariance Determinant (MCD) ROC: 0.9164, precision @ rank n: 0.6, execution time: 0.0222s'
# One-class SVM (OCSVM) ROC: 0.9636, precision @ rank n: 0.6, execution time: 0.0081s'
# Principal Component Analysis (PCA) ROC: 0.9818, precision @ rank n: 0.8, execution time: 0.0s'
#
# ... Processing mnist.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.7813, precision @ rank n: 0.3562, execution time: 6.8952s'
# Cluster-based Local Outlier Factor ROC: 0.8447, precision @ rank n: 0.4007, execution time: 1.0804s'
# Feature Bagging ROC: 0.7259, precision @ rank n: 0.3664, execution time: 47.832s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.5675, precision @ rank n: 0.1199, execution time: 0.0427s'
# Isolation Forest ROC: 0.7801, precision @ rank n: 0.2979, execution time: 1.6987s'
# K Nearest Neighbors (KNN) ROC: 0.8409, precision @ rank n: 0.4144, execution time: 5.35s'
# Local Outlier Factor (LOF) ROC: 0.7085, precision @ rank n: 0.339, execution time: 5.1114s'
# Minimum Covariance Determinant (MCD) ROC: 0.863, precision @ rank n: 0.3973, execution time: 2.5107s'
# One-class SVM (OCSVM) ROC: 0.8417, precision @ rank n: 0.3801, execution time: 3.821s'
# Principal Component Analysis (PCA) ROC: 0.8396, precision @ rank n: 0.3767, execution time: 0.142s'
#
# ... Processing musk.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.0809, precision @ rank n: 0.0333, execution time: 1.8161s'
# Cluster-based Local Outlier Factor ROC: 1.0, precision @ rank n: 1.0, execution time: 0.2935s'
# Feature Bagging ROC: 0.5228, precision @ rank n: 0.1667, execution time: 11.1679s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9999, precision @ rank n: 0.9667, execution time: 0.0584s'
# Isolation Forest ROC: 0.9996, precision @ rank n: 0.9333, execution time: 1.117s'
# K Nearest Neighbors (KNN) ROC: 0.7348, precision @ rank n: 0.2333, execution time: 1.5127s'
# Local Outlier Factor (LOF) ROC: 0.5323, precision @ rank n: 0.1333, execution time: 1.514s'
# Minimum Covariance Determinant (MCD) ROC: 1.0, precision @ rank n: 0.9667, execution time: 10.7253s'
# One-class SVM (OCSVM) ROC: 1.0, precision @ rank n: 1.0, execution time: 1.2228s'
# Principal Component Analysis (PCA) ROC: 1.0, precision @ rank n: 1.0, execution time: 0.1486s'
#
# ... Processing optdigits.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.4428, precision @ rank n: 0.0161, execution time: 2.3563s'
# Cluster-based Local Outlier Factor ROC: 0.7852, precision @ rank n: 0.0, execution time: 0.4036s'
# Feature Bagging ROC: 0.4641, precision @ rank n: 0.0484, execution time: 11.7291s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.8822, precision @ rank n: 0.2581, execution time: 0.0203s'
# Isolation Forest ROC: 0.5764, precision @ rank n: 0.0161, execution time: 0.7242s'
# K Nearest Neighbors (KNN) ROC: 0.3824, precision @ rank n: 0.0, execution time: 1.4322s'
# Local Outlier Factor (LOF) ROC: 0.4584, precision @ rank n: 0.0484, execution time: 1.323s'
# Minimum Covariance Determinant (MCD) ROC: 0.3486, precision @ rank n: 0.0, execution time: 0.9881s'
# One-class SVM (OCSVM) ROC: 0.4972, precision @ rank n: 0.0, execution time: 1.232s'
# Principal Component Analysis (PCA) ROC: 0.504, precision @ rank n: 0.0, execution time: 0.0404s'
#
# ... Processing pendigits.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.7008, precision @ rank n: 0.0308, execution time: 1.2572s'
# Cluster-based Local Outlier Factor ROC: 0.9609, precision @ rank n: 0.3077, execution time: 0.2195s'
# Feature Bagging ROC: 0.4687, precision @ rank n: 0.0462, execution time: 3.8793s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9294, precision @ rank n: 0.2615, execution time: 0.008s'
# Isolation Forest ROC: 0.9422, precision @ rank n: 0.2769, execution time: 0.54s'
# K Nearest Neighbors (KNN) ROC: 0.7602, precision @ rank n: 0.0462, execution time: 0.5066s'
# Local Outlier Factor (LOF) ROC: 0.481, precision @ rank n: 0.0462, execution time: 0.4795s'
# Minimum Covariance Determinant (MCD) ROC: 0.8271, precision @ rank n: 0.0615, execution time: 1.688s'
# One-class SVM (OCSVM) ROC: 0.93, precision @ rank n: 0.2923, execution time: 0.8283s'
# Principal Component Analysis (PCA) ROC: 0.9332, precision @ rank n: 0.3385, execution time: 0.0101s'
#
# ... Processing pima.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.6757, precision @ rank n: 0.5106, execution time: 0.1409s'
# Cluster-based Local Outlier Factor ROC: 0.684, precision @ rank n: 0.4681, execution time: 0.0759s'
# Feature Bagging ROC: 0.6446, precision @ rank n: 0.4468, execution time: 0.0812s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.7169, precision @ rank n: 0.5213, execution time: 0.0s'
# Isolation Forest ROC: 0.6604, precision @ rank n: 0.4787, execution time: 0.315s'
# K Nearest Neighbors (KNN) ROC: 0.7252, precision @ rank n: 0.5106, execution time: 0.0297s'
# Local Outlier Factor (LOF) ROC: 0.6604, precision @ rank n: 0.4787, execution time: 0.0012s'
# Minimum Covariance Determinant (MCD) ROC: 0.7047, precision @ rank n: 0.4787, execution time: 0.0424s'
# One-class SVM (OCSVM) ROC: 0.6423, precision @ rank n: 0.4574, execution time: 0.0101s'
# Principal Component Analysis (PCA) ROC: 0.6639, precision @ rank n: 0.5, execution time: 0.0s'
#
# ... Processing satellite.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.5681, precision @ rank n: 0.3918, execution time: 1.5838s'
# Cluster-based Local Outlier Factor ROC: 0.7234, precision @ rank n: 0.5574, execution time: 0.3344s'
# Feature Bagging ROC: 0.557, precision @ rank n: 0.4051, execution time: 5.9507s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.7393, precision @ rank n: 0.5466, execution time: 0.0101s'
# Isolation Forest ROC: 0.6843, precision @ rank n: 0.5719, execution time: 0.6348s'
# K Nearest Neighbors (KNN) ROC: 0.6781, precision @ rank n: 0.4994, execution time: 0.8577s'
# Local Outlier Factor (LOF) ROC: 0.5551, precision @ rank n: 0.4051, execution time: 0.7994s'
# Minimum Covariance Determinant (MCD) ROC: 0.792, precision @ rank n: 0.6747, execution time: 1.663s'
# One-class SVM (OCSVM) ROC: 0.636, precision @ rank n: 0.5224, execution time: 1.1194s'
# Principal Component Analysis (PCA) ROC: 0.5783, precision @ rank n: 0.4559, execution time: 0.0201s'
#
# ... Processing satimage-2.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.86, precision @ rank n: 0.2593, execution time: 1.4317s'
# Cluster-based Local Outlier Factor ROC: 0.9987, precision @ rank n: 0.8889, execution time: 0.2821s'
# Feature Bagging ROC: 0.4971, precision @ rank n: 0.0741, execution time: 5.1619s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9837, precision @ rank n: 0.5926, execution time: 0.0181s'
# Isolation Forest ROC: 0.9962, precision @ rank n: 0.8889, execution time: 0.5861s'
# K Nearest Neighbors (KNN) ROC: 0.9505, precision @ rank n: 0.3704, execution time: 0.7697s'
# Local Outlier Factor (LOF) ROC: 0.5006, precision @ rank n: 0.0741, execution time: 0.6404s'
# Minimum Covariance Determinant (MCD) ROC: 0.9946, precision @ rank n: 0.5185, execution time: 1.7813s'
# One-class SVM (OCSVM) ROC: 0.9976, precision @ rank n: 0.9259, execution time: 0.9712s'
# Principal Component Analysis (PCA) ROC: 0.9841, precision @ rank n: 0.8519, execution time: 0.0202s'
#
# ... Processing shuttle.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.6186, precision @ rank n: 0.1918, execution time: 13.259s'
# Cluster-based Local Outlier Factor ROC: 0.6287, precision @ rank n: 0.2336, execution time: 0.978s'
# Feature Bagging ROC: 0.5211, precision @ rank n: 0.111, execution time: 41.8967s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9851, precision @ rank n: 0.9857, execution time: 0.0122s'
# Isolation Forest ROC: 0.997, precision @ rank n: 0.9308, execution time: 2.7864s'
# K Nearest Neighbors (KNN) ROC: 0.645, precision @ rank n: 0.2199, execution time: 7.5195s'
# Local Outlier Factor (LOF) ROC: 0.5347, precision @ rank n: 0.1406, execution time: 10.297s'
# Minimum Covariance Determinant (MCD) ROC: 0.9903, precision @ rank n: 0.7534, execution time: 10.6522s'
# One-class SVM (OCSVM) ROC: 0.9922, precision @ rank n: 0.9553, execution time: 35.7553s'
# Principal Component Analysis (PCA) ROC: 0.9902, precision @ rank n: 0.9503, execution time: 0.0304s'
#
# ... Processing shuttle.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.6227, precision @ rank n: 0.1938, execution time: 13.6011s'
# Cluster-based Local Outlier Factor ROC: 0.6578, precision @ rank n: 0.2206, execution time: 1.0104s'
# Feature Bagging ROC: 0.5023, precision @ rank n: 0.0669, execution time: 43.794s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9868, precision @ rank n: 0.9386, execution time: 0.0202s'
# Isolation Forest ROC: 0.9974, precision @ rank n: 0.9486, execution time: 2.8423s'
# K Nearest Neighbors (KNN) ROC: 0.6549, precision @ rank n: 0.2213, execution time: 6.5217s'
# Local Outlier Factor (LOF) ROC: 0.5336, precision @ rank n: 0.155, execution time: 9.5496s'
# Minimum Covariance Determinant (MCD) ROC: 0.9897, precision @ rank n: 0.7477, execution time: 9.0045s'
# One-class SVM (OCSVM) ROC: 0.9923, precision @ rank n: 0.9605, execution time: 36.9716s'
# Principal Component Analysis (PCA) ROC: 0.9907, precision @ rank n: 0.9577, execution time: 0.0283s'
#
# ... Processing vertebral.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.3688, precision @ rank n: 0.0, execution time: 0.0503s'
# Cluster-based Local Outlier Factor ROC: 0.3891, precision @ rank n: 0.0, execution time: 0.0485s'
# Feature Bagging ROC: 0.3688, precision @ rank n: 0.0, execution time: 0.0302s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.3617, precision @ rank n: 0.0, execution time: 0.0s'
# Isolation Forest ROC: 0.3539, precision @ rank n: 0.0, execution time: 0.2532s'
# K Nearest Neighbors (KNN) ROC: 0.3562, precision @ rank n: 0.0, execution time: 0.0082s'
# Local Outlier Factor (LOF) ROC: 0.3562, precision @ rank n: 0.0, execution time: 0.0s'
# Minimum Covariance Determinant (MCD) ROC: 0.4203, precision @ rank n: 0.0, execution time: 0.0256s'
# One-class SVM (OCSVM) ROC: 0.4078, precision @ rank n: 0.0, execution time: 0.0s'
# Principal Component Analysis (PCA) ROC: 0.3633, precision @ rank n: 0.0625, execution time: 0.0s'
#
# ... Processing vowels.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.8982, precision @ rank n: 0.2857, execution time: 0.285s'
# Cluster-based Local Outlier Factor ROC: 0.8608, precision @ rank n: 0.2143, execution time: 0.0846s'
# Feature Bagging ROC: 0.9124, precision @ rank n: 0.2143, execution time: 0.247s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.7567, precision @ rank n: 0.2143, execution time: 0.0156s'
# Isolation Forest ROC: 0.8141, precision @ rank n: 0.1429, execution time: 0.2881s'
# K Nearest Neighbors (KNN) ROC: 0.9746, precision @ rank n: 0.3571, execution time: 0.066s'
# Local Outlier Factor (LOF) ROC: 0.9192, precision @ rank n: 0.2857, execution time: 0.0312s'
# Minimum Covariance Determinant (MCD) ROC: 0.6966, precision @ rank n: 0.0714, execution time: 0.6169s'
# One-class SVM (OCSVM) ROC: 0.8426, precision @ rank n: 0.2857, execution time: 0.0378s'
# Principal Component Analysis (PCA) ROC: 0.6907, precision @ rank n: 0.2143, execution time: 0.0s'
#
# ... Processing wbc.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.9573, precision @ rank n: 0.5556, execution time: 0.0625s'
# Cluster-based Local Outlier Factor ROC: 0.9751, precision @ rank n: 0.6667, execution time: 0.0423s'
# Feature Bagging ROC: 0.979, precision @ rank n: 0.7778, execution time: 0.079s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9876, precision @ rank n: 0.6667, execution time: 0.009s'
# Isolation Forest ROC: 0.9674, precision @ rank n: 0.5556, execution time: 0.2795s'
# K Nearest Neighbors (KNN) ROC: 0.9713, precision @ rank n: 0.4444, execution time: 0.0101s'
# Local Outlier Factor (LOF) ROC: 0.979, precision @ rank n: 0.6667, execution time: 0.002s'
# Minimum Covariance Determinant (MCD) ROC: 0.9658, precision @ rank n: 0.5556, execution time: 0.0585s'
# One-class SVM (OCSVM) ROC: 0.9782, precision @ rank n: 0.6667, execution time: 0.0s'
# Principal Component Analysis (PCA) ROC: 0.9775, precision @ rank n: 0.6667, execution time: 0.0081s'

# %%
roc_df
# Out:
#          Data #Sample #Dimensions Outlier Perc     PCA     MCD   OCSVM  \
# 0  arrhythmia     452         274      14.6018  0.7687  0.7684  0.7799
# 0      cardio    1831          21       9.6122  0.5763  0.8221  0.4879
# 0       glass     214           9       4.2056  0.7104  0.8506  0.7043
# 0  ionosphere     351          33      35.8974  0.9004  0.8952  0.8933
# 0      letter    1600          32         6.25  0.8465  0.7423   0.866
# 0      lympho     148          18       4.0541  0.9382  0.9709  0.9673
# 0       mnist    7603         100       9.2069  0.7813  0.8447  0.7259
# 0        musk    3062         166       3.1679  0.0809       1  0.5228
# 0   optdigits    5216          64       2.8758  0.4428  0.7852  0.4641
# 0   pendigits    6870          16       2.2707  0.7008  0.9609  0.4687
# 0        pima     768           8      34.8958  0.6757   0.684  0.6446
# 0   satellite    6435          36      31.6395  0.5681  0.7234   0.557
# 0  satimage-2    5803          36       1.2235    0.86  0.9987  0.4971
# 0     shuttle   49097           9       7.1511  0.6186  0.6287  0.5211
# 0     shuttle   49097           9       7.1511  0.6227  0.6578  0.5023
# 0   vertebral     240           6         12.5  0.3688  0.3891  0.3688
# 0      vowels    1456          12       3.4341  0.8982  0.8608  0.9124
# 0         wbc     378          30       5.5556  0.9573  0.9751   0.979
#
#       LOF   CBLOF     KNN    HBOS    ABOD IFOREST FEATUREBAGGING
# 0  0.8511  0.8527   0.782  0.7787  0.8228  0.7986         0.7997
# 0  0.8453  0.9414  0.6959  0.4715  0.8778  0.9507         0.9638
# 0  0.6524  0.7195  0.7805  0.7774  0.7165  0.6189          0.622
# 0  0.5195  0.8309  0.9134  0.8989  0.9399  0.8372         0.7971
# 0  0.5728  0.5778   0.845  0.8409  0.7499  0.5744           0.48
# 0  0.9964  0.9855  0.9636  0.9636  0.9164  0.9636         0.9818
# 0  0.5675  0.7801  0.8409  0.7085   0.863  0.8417         0.8396
# 0  0.9999  0.9996  0.7348  0.5323       1       1              1
# 0  0.8822  0.5764  0.3824  0.4584  0.3486  0.4972          0.504
# 0  0.9294  0.9422  0.7602   0.481  0.8271    0.93         0.9332
# 0  0.7169  0.6604  0.7252  0.6604  0.7047  0.6423         0.6639
# 0  0.7393  0.6843  0.6781  0.5551   0.792   0.636         0.5783
# 0  0.9837  0.9962  0.9505  0.5006  0.9946  0.9976         0.9841
# 0  0.9851   0.997   0.645  0.5347  0.9903  0.9922         0.9902
# 0  0.9868  0.9974  0.6549  0.5336  0.9897  0.9923         0.9907
# 0  0.3617  0.3539  0.3562  0.3562  0.4203  0.4078         0.3633
# 0  0.7567  0.8141  0.9746  0.9192  0.6966  0.8426         0.6907
# 0  0.9876  0.9674  0.9713   0.979  0.9658  0.9782         0.9775

# %%
prn_df
# Out:
#          Data #Sample #Dimensions Outlier Perc     PCA     MCD   OCSVM  \
# 0  arrhythmia     452         274      14.6018  0.3571  0.4643     0.5
# 0      cardio    1831          21       9.6122  0.1875  0.4844  0.1406
# 0       glass     214           9       4.2056    0.25    0.25    0.25
# 0  ionosphere     351          33      35.8974  0.8214  0.8036    0.75
# 0      letter    1600          32         6.25   0.275   0.175     0.4
# 0      lympho     148          18       4.0541     0.4     0.6     0.6
# 0       mnist    7603         100       9.2069  0.3562  0.4007  0.3664
# 0        musk    3062         166       3.1679  0.0333       1  0.1667
# 0   optdigits    5216          64       2.8758  0.0161       0  0.0484
# 0   pendigits    6870          16       2.2707  0.0308  0.3077  0.0462
# 0        pima     768           8      34.8958  0.5106  0.4681  0.4468
# 0   satellite    6435          36      31.6395  0.3918  0.5574  0.4051
# 0  satimage-2    5803          36       1.2235  0.2593  0.8889  0.0741
# 0     shuttle   49097           9       7.1511  0.1918  0.2336   0.111
# 0     shuttle   49097           9       7.1511  0.1938  0.2206  0.0669
# 0   vertebral     240           6         12.5       0       0       0
# 0      vowels    1456          12       3.4341  0.2857  0.2143  0.2143
# 0         wbc     378          30       5.5556  0.5556  0.6667  0.7778
#
#       LOF   CBLOF     KNN    HBOS    ABOD IFOREST FEATUREBAGGING
# 0  0.5714  0.5714     0.5  0.4643  0.4286     0.5            0.5
# 0  0.4688     0.5  0.2812   0.125  0.3906  0.5938         0.6875
# 0       0    0.25    0.25    0.25       0    0.25           0.25
# 0  0.3393  0.6607  0.8393    0.75  0.8571  0.7143         0.5893
# 0   0.125    0.05     0.3   0.325   0.075     0.1           0.05
# 0     0.8     0.6     0.6     0.6     0.6     0.6            0.8
# 0  0.1199  0.2979  0.4144   0.339  0.3973  0.3801         0.3767
# 0  0.9667  0.9333  0.2333  0.1333  0.9667       1              1
# 0  0.2581  0.0161       0  0.0484       0       0              0
# 0  0.2615  0.2769  0.0462  0.0462  0.0615  0.2923         0.3385
# 0  0.5213  0.4787  0.5106  0.4787  0.4787  0.4574            0.5
# 0  0.5466  0.5719  0.4994  0.4051  0.6747  0.5224         0.4559
# 0  0.5926  0.8889  0.3704  0.0741  0.5185  0.9259         0.8519
# 0  0.9857  0.9308  0.2199  0.1406  0.7534  0.9553         0.9503
# 0  0.9386  0.9486  0.2213   0.155  0.7477  0.9605         0.9577
# 0       0       0       0       0       0       0         0.0625
# 0  0.2143  0.1429  0.3571  0.2857  0.0714  0.2857         0.2143
# 0  0.6667  0.5556  0.4444  0.6667  0.5556  0.6667         0.6667

# %%
time_df
# Out:
#          Data #Sample #Dimensions Outlier Perc      PCA     MCD    OCSVM  \
# 0  arrhythmia     452         274      14.6018   1.0649  1.6181   0.6234
# 0      cardio    1831          21       9.6122   0.3814  0.1805    0.943
# 0       glass     214           9       4.2056   0.0583  0.0588   0.0503
# 0  ionosphere     351          33      35.8974   0.0904  0.0605   0.0784
# 0      letter    1600          32         6.25    0.354  0.1159   0.6246
# 0      lympho     148          18       4.0541   0.0201  0.0403   0.0282
# 0       mnist    7603         100       9.2069   6.8952  1.0804   47.832
# 0        musk    3062         166       3.1679   1.8161  0.2935  11.1679
# 0   optdigits    5216          64       2.8758   2.3563  0.4036  11.7291
# 0   pendigits    6870          16       2.2707   1.2572  0.2195   3.8793
# 0        pima     768           8      34.8958   0.1409  0.0759   0.0812
# 0   satellite    6435          36      31.6395   1.5838  0.3344   5.9507
# 0  satimage-2    5803          36       1.2235   1.4317  0.2821   5.1619
# 0     shuttle   49097           9       7.1511   13.259   0.978  41.8967
# 0     shuttle   49097           9       7.1511  13.6011  1.0104   43.794
# 0   vertebral     240           6         12.5   0.0503  0.0485   0.0302
# 0      vowels    1456          12       3.4341    0.285  0.0846    0.247
# 0         wbc     378          30       5.5556   0.0625  0.0423    0.079
#
#       LOF   CBLOF     KNN    HBOS     ABOD  IFOREST FEATUREBAGGING
# 0  1.8258  0.3427   0.069  0.0625   0.5854   0.0377         0.0469
# 0  0.0101  0.4605  0.1856  0.1192   0.5936   0.0988              0
# 0   0.002  0.3516  0.0181       0   0.0402        0              0
# 0  0.0101  0.4242  0.0156  0.0156   0.0534        0         0.0156
# 0  0.0101  0.3147  0.1112  0.0707   0.9389   0.0826          0.002
# 0  0.0063   0.244   0.002   0.008   0.0222   0.0081              0
# 0  0.0427  1.6987    5.35  5.1114   2.5107    3.821          0.142
# 0  0.0584   1.117  1.5127   1.514  10.7253   1.2228         0.1486
# 0  0.0203  0.7242  1.4322   1.323   0.9881    1.232         0.0404
# 0   0.008    0.54  0.5066  0.4795    1.688   0.8283         0.0101
# 0       0   0.315  0.0297  0.0012   0.0424   0.0101              0
# 0  0.0101  0.6348  0.8577  0.7994    1.663   1.1194         0.0201
# 0  0.0181  0.5861  0.7697  0.6404   1.7813   0.9712         0.0202
# 0  0.0122  2.7864  7.5195  10.297  10.6522  35.7553         0.0304
# 0  0.0202  2.8423  6.5217  9.5496   9.0045  36.9716         0.0283
# 0       0  0.2532  0.0082       0   0.0256        0              0
# 0  0.0156  0.2881   0.066  0.0312   0.6169   0.0378              0
# 0   0.009  0.2795  0.0101   0.002   0.0585        0         0.0081
